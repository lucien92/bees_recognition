# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Téléchargement de la base de données

# %%
# Pour récupérer le nombre de classes du training dataset
from tensorflow import keras
from tensorflow.keras import layers

# %%
# !git clone https://github.com/fabiopereira59/abeilles-cap500
# Out:
# Cloning into 'abeilles-cap500'...
# remote: Enumerating objects: 24878, done.
# remote: Counting objects: 100% (6126/6126), done.
# remote: Compressing objects: 100% (6121/6121), done.
# remote: Total 24878 (delta 2), reused 6126 (delta 2), pack-reused 18752
# Receiving objects: 100% (24878/24878), 242.93 MiB | 16.59 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Checking out files: 100% (24081/24081), done.

# %%
IMG_SIZE = 224
train_ds = keras.utils.image_dataset_from_directory(
    directory='abeilles-cap500/train/',
    labels='inferred',
    label_mode='categorical',
    shuffle = False,
    batch_size=16,
    image_size=(IMG_SIZE, IMG_SIZE))
# Out:
# Found 14917 files belonging to 71 classes.

# %%
CLASS_NAMES = train_ds.class_names
print(CLASS_NAMES)
NB_CLASSES = len(CLASS_NAMES)
print(NB_CLASSES)
# Out:
# ['Amegilla quadrifasciata', 'Andrena agilissima', 'Andrena bicolor', 'Andrena cineraria', 'Andrena clarkella', 'Andrena denticulata', 'Andrena flavipes', 'Andrena florea', 'Andrena fulva', 'Andrena gravida', 'Andrena haemorrhoa', 'Andrena hattorfiana', 'Andrena nigroaenea', 'Andrena nitida', 'Andrena nycthemera', 'Andrena thoracica', 'Andrena vaga', 'Andrena ventralis', 'Anthidiellum strigatum', 'Anthidium florentinum', 'Anthidium manicatum', 'Anthidium oblongatum', 'Anthidium septemspinosum', 'Anthophora bimaculata', 'Anthophora furcata', 'Anthophora plumipes', 'Apis mellifera', 'Bombus argillaceus', 'Bombus bohemicus', 'Bombus campestris', 'Bombus hortorum', 'Bombus humilis', 'Bombus hypnorum', 'Bombus lapidarius', 'Bombus lucorum', 'Bombus muscorum', 'Bombus pascuorum', 'Bombus pratorum', 'Bombus ruderatus', 'Bombus rupestris', 'Bombus sylvarum', 'Bombus terrestris lusitanicus', 'Bombus vestalis', 'Ceratina cucurbitina', 'Chelostoma florisomne', 'Colletes cunicularius', 'Colletes hederae', 'Dasypoda hirtipes', 'Halictus rubicundus', 'Halictus scabiosae', 'Halictus sexcinctus', 'Heriades truncorum', 'Hylaeus variegatus', 'Lithurgus chrysurus', 'Macropis europaea', 'Megachile centuncularis', 'Megachile ericetorum', 'Megachile sculpturalis', 'Melecta albifrons', 'Nomada goodeniana', 'Nomada lathburiana', 'Osmia aurulenta', 'Osmia bicolor', 'Osmia bicornis', 'Osmia caerulescens', 'Osmia cornuta', 'Rhodanthidium septemdentatum', 'Rhodanthidium sticticum', 'Sphecodes albilabris', 'Xylocopa valga', 'Xylocopa violacea']
# 71

# %% [markdown]
# ## Chargement des données

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Paramètres
IMG_SIZE = 224 # pour utiliser ResNet

# %%
# Récupération des dataset pour l'entraînement (train, val)
train_ds = keras.utils.image_dataset_from_directory(
    directory='abeilles-cap500/train/',
    labels='inferred',
    label_mode='categorical',
    shuffle = False,
    batch_size=16,
    image_size=(IMG_SIZE, IMG_SIZE))

validation_ds = keras.utils.image_dataset_from_directory(
    directory='abeilles-cap500/val/',
    labels='inferred',
    label_mode='categorical',
    batch_size=16,
    image_size=(IMG_SIZE, IMG_SIZE))
# Out:
# Found 14917 files belonging to 71 classes.
# Found 1832 files belonging to 71 classes.

# %%
len(train_ds.file_paths)
# Out:
# 14917

# %% [markdown]
# ## Création du modèle

# %%
# !pip uninstall opencv-python-headless==4.5.5.62
# !pip install opencv-python-headless==4.1.2.30
# !pip install -q -U albumentations
# !echo "$(pip freeze | grep albumentations) is successfully installed"
# Out:
# WARNING: Skipping opencv-python-headless as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python-headless==4.1.2.30
#   Downloading opencv_python_headless-4.1.2.30-cp37-cp37m-manylinux1_x86_64.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 1.3 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python-headless==4.1.2.30) (1.21.6)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.1.2.30
#      |████████████████████████████████| 116 kB 34.9 MB/s
# albumentations==1.2.1 is successfully installed

# %%
from albumentations import (Compose, Rotate, HorizontalFlip, VerticalFlip, Affine, RandomBrightnessContrast, ChannelShuffle)
import albumentations as A

AUGMENTATIONS_TRAIN = Compose([
    Rotate(limit=[0,100], p=0.5),
    HorizontalFlip(p=0.5),
    VerticalFlip(p=0.5),
    Affine(shear=[-45, 45], p=0.5),
    RandomBrightnessContrast(p=0.5)
])

# %%
import numpy as np

x_train = np.array(train_ds.file_paths)
y_train = np.zeros((14917, NB_CLASSES))

ind_data = 0
for bx, by in train_ds.as_numpy_iterator():
  y_train[ind_data:ind_data+bx.shape[0]] = by
  ind_data += bx.shape[0]

# %%
def color_preprocessing(x):
    x = x.astype('float32')
    mean = [125.3, 123.0, 113.9]
    std  = [63.0,  62.1,  66.7]
    for i in range(3):
        x[:,:,:,i] = (x[:,:,:,i] - mean[i]) / std[i]
    return x

# %%
from tensorflow.keras.utils import Sequence
import numpy as np
import cv2 as cv

class AbeillesSequence(Sequence):
    # Initialisation de la séquence avec différents paramètres
    def __init__(self, x_train, y_train, batch_size, augmentations):
        self.x_train = x_train
        self.y_train = y_train
        self.classes = CLASS_NAMES
        self.batch_size = batch_size
        self.augment = augmentations
        self.indices1 = np.arange(len(x_train))
        np.random.shuffle(self.indices1) # Les indices permettent d'accéder
        # aux données et sont randomisés à chaque epoch pour varier la composition
        # des batches au cours de l'entraînement

    # Fonction calculant le nombre de pas de descente du gradient par epoch
    def __len__(self):
        return int(np.ceil(x_train.shape[0] / float(self.batch_size)))
    
    # Application de l'augmentation de données à chaque image du batch
    def apply_augmentation(self, bx, by):

        batch_x = np.zeros((bx.shape[0], IMG_SIZE, IMG_SIZE, 3))
        batch_y = by
        
        # Pour chaque image du batch
        for i in range(len(bx)):
            class_labels = []
            class_id = np.argmax(by[i])
            class_labels.append(self.classes[class_id])

            # Application de l'augmentation à l'image et aux masques
            img = cv.imread(bx[i])
            img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
            transformed = self.augment(image=img)
            batch_x[i] = transformed['image']
            #print(batch_x[i])
      
        return batch_x, batch_y

    # Fonction appelée à chaque nouveau batch : sélection et augmentation des données
    # idx = position du batch (idx = 5 => on prend le 5ème batch)
    def __getitem__(self, idx):
        batch_x = self.x_train[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_y = self.y_train[self.indices1[idx * self.batch_size:(idx + 1) * self.batch_size]]
           
        batch_x, batch_y = self.apply_augmentation(batch_x, batch_y)

        # Normalisation des données
        batch_x = color_preprocessing(batch_x)
        
        return batch_x, batch_y

    # Fonction appelée à la fin d'un epoch ; on randomise les indices d'accès aux données
    def on_epoch_end(self):
        np.random.shuffle(self.indices1)

# %%
from tensorflow.keras import regularizers
from tensorflow.keras import optimizers
import tensorflow as tf

# %%
from tensorflow import keras 
import numpy as np
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
from keras.layers import Conv2D, Dense, Input, add, Activation, Flatten, AveragePooling2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.callbacks import LearningRateScheduler, TensorBoard
from keras.regularizers import l2
from keras import optimizers
from keras.models import Model

WEIGHT_DECAY = 0.0005

def create_WideResNet50(width=1, img_rows=224, img_cols=224, img_channels=3, nb_classes=1000):

  # Input
  img_input = Input(shape=(img_rows,img_cols,img_channels))

  # first_filter : nb de filtres de la première conv
  # reduction : True si on doit diviser la dimension de l'entrée
  def residual_layer(input, first_filter, reduction=False, first_layer=False):

    conv = Conv2D(filters=width*first_filter, kernel_size=(1,1), strides=(1,1),
        kernel_initializer='he_normal',
        kernel_regularizer=l2(WEIGHT_DECAY))(input)
    conv = BatchNormalization(momentum=0.9, epsilon=1e-5)(conv)
    conv = Activation('relu')(conv)

    if (reduction):
      conv = Conv2D(filters=width*first_filter, kernel_size=(3,3), strides=(2,2), padding='same',
              kernel_initializer='he_normal',
              kernel_regularizer=l2(WEIGHT_DECAY))(conv)
    else:
      conv = Conv2D(filters=width*first_filter, kernel_size=(3,3), strides=(1,1), padding='same',
              kernel_initializer='he_normal',
              kernel_regularizer=l2(WEIGHT_DECAY))(conv)
    conv = BatchNormalization(momentum=0.9, epsilon=1e-5)(conv)
    conv = Activation('relu')(conv)

    conv = Conv2D(filters=4*first_filter, kernel_size=(1,1), strides=(1,1),
            kernel_initializer='he_normal',
            kernel_regularizer=l2(WEIGHT_DECAY))(conv)
    conv = BatchNormalization(momentum=0.9, epsilon=1e-5)(conv)

    if (first_layer):
      conv2 = Conv2D(filters = 256, kernel_size=(1,1), strides=(1,1),
          kernel_initializer='he_normal',
          kernel_regularizer=l2(WEIGHT_DECAY))(x)
      conv2 = BatchNormalization(momentum=0.9, epsilon=1e-5)(conv2)
    else:
      if (reduction):
        conv2 = Conv2D(filters = 4*first_filter, kernel_size=(1,1), strides=(2,2),
                kernel_initializer='he_normal',
                kernel_regularizer=l2(WEIGHT_DECAY))(x)
        conv2 = BatchNormalization(momentum=0.9, epsilon=1e-5)(conv2)
      else:
        conv2 = input
    
    return add([conv, conv2])
  
  x = ZeroPadding2D(padding=(3,3))(img_input)
  x = Conv2D(filters=64, kernel_size=(7,7), strides=(2,2),
        kernel_initializer='he_normal',
        kernel_regularizer=l2(WEIGHT_DECAY))(x)
  x = BatchNormalization(momentum=0.9, epsilon=1e-5)(x)
  x = Activation('relu')(x)
  x = ZeroPadding2D(padding=(1,1))(x)
  x = MaxPooling2D(pool_size=(3, 3), strides=(2,2))(x)

  # Premier bloc résiduel
  x = residual_layer(x, 64, reduction=False, first_layer=True)
  for i in range(2): 
    x = Activation('relu')(x)
    x = residual_layer(x, 64, reduction=False)

  # Second bloc
  x = Activation('relu')(x)
  x = residual_layer(x, 128, reduction=True)
  for i in range(3): 
    x = Activation('relu')(x)
    x = residual_layer(x, 128, reduction=False)
  
  # Troisième bloc
  x = Activation('relu')(x)
  x = residual_layer(x, 256, reduction=True)
  for i in range(5): 
    x = Activation('relu')(x)
    x = residual_layer(x, 256, reduction=False)

  # Quatrième bloc
  x = Activation('relu')(x)
  x = residual_layer(x, 512, reduction=True)
  for i in range(2): 
    x = Activation('relu')(x)
    x = residual_layer(x, 512, reduction=False)

  x = GlobalAveragePooling2D()(x)
  x = Flatten()(x)
  x = Dense(nb_classes,
      activation='softmax',
      kernel_initializer='he_normal',
      kernel_regularizer=l2(WEIGHT_DECAY))(x)
  
  return Model(img_input, x)

# %%
model = create_WideResNet50(width=2, img_rows=224, img_cols=224, img_channels=3, nb_classes=NB_CLASSES)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 230, 230, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv2d_53 (Conv2D)             (None, 112, 112, 64  9472        ['zero_padding2d_2[0][0]']
#                                 )
#
#  batch_normalization_53 (BatchN  (None, 112, 112, 64  256        ['conv2d_53[0][0]']
#  ormalization)                  )
#
#  activation_48 (Activation)     (None, 112, 112, 64  0           ['batch_normalization_53[0][0]']
#                                 )
#
#  zero_padding2d_3 (ZeroPadding2  (None, 114, 114, 64  0          ['activation_48[0][0]']
#  D)                             )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['zero_padding2d_3[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 56, 56, 128)  8320        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 56, 56, 128)  512        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 56, 56, 128)  147584      ['activation_49[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 56, 56, 128)  512        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 56, 56, 256)  33024       ['activation_50[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 56, 56, 256)  16640       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_57[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 56, 56, 256)  0           ['batch_normalization_56[0][0]',
#                                                                   'batch_normalization_57[0][0]']
#
#  activation_51 (Activation)     (None, 56, 56, 256)  0           ['add_16[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 56, 56, 128)  32896       ['activation_51[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 56, 56, 128)  512        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 56, 56, 128)  147584      ['activation_52[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 56, 56, 128)  512        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_59[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 56, 56, 256)  33024       ['activation_53[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_60[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 56, 56, 256)  0           ['batch_normalization_60[0][0]',
#                                                                   'activation_51[0][0]']
#
#  activation_54 (Activation)     (None, 56, 56, 256)  0           ['add_17[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 56, 56, 128)  32896       ['activation_54[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 56, 56, 128)  512        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 56, 56, 128)  147584      ['activation_55[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 56, 56, 128)  512        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 56, 56, 256)  33024       ['activation_56[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_63[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 56, 56, 256)  0           ['batch_normalization_63[0][0]',
#                                                                   'activation_54[0][0]']
#
#  activation_57 (Activation)     (None, 56, 56, 256)  0           ['add_18[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 56, 56, 256)  65792       ['activation_57[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 56, 56, 256)  1024       ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 56, 56, 256)  0           ['batch_normalization_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 28, 28, 256)  590080      ['activation_58[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_65[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 28, 28, 512)  131584      ['activation_59[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 28, 28, 512)  131584      ['activation_57[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_66[0][0]']
#  ormalization)
#
#  batch_normalization_67 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_67[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_66[0][0]',
#                                                                   'batch_normalization_67[0][0]']
#
#  activation_60 (Activation)     (None, 28, 28, 512)  0           ['add_19[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 28, 28, 256)  131328      ['activation_60[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 28, 28, 256)  590080      ['activation_61[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_69[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_69[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 28, 28, 512)  131584      ['activation_62[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_70[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_70[0][0]',
#                                                                   'activation_60[0][0]']
#
#  activation_63 (Activation)     (None, 28, 28, 512)  0           ['add_20[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 28, 28, 256)  131328      ['activation_63[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_71[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 28, 28, 256)  590080      ['activation_64[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_72[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_72[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 28, 28, 512)  131584      ['activation_65[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_73[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_73[0][0]',
#                                                                   'activation_63[0][0]']
#
#  activation_66 (Activation)     (None, 28, 28, 512)  0           ['add_21[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 28, 28, 256)  131328      ['activation_66[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 28, 28, 256)  590080      ['activation_67[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_75[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_75[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 28, 28, 512)  131584      ['activation_68[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_76[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 28, 28, 512)  0           ['batch_normalization_76[0][0]',
#                                                                   'activation_66[0][0]']
#
#  activation_69 (Activation)     (None, 28, 28, 512)  0           ['add_22[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 28, 28, 512)  262656      ['activation_69[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_77[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_77[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 14, 14, 512)  2359808     ['activation_70[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_78[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_78[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_71[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_69[0][0]']
#                                 )
#
#  batch_normalization_79 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_79[0][0]']
#  ormalization)                  )
#
#  batch_normalization_80 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_80[0][0]']
#  ormalization)                  )
#
#  add_23 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_79[0][0]',
#                                 )                                 'batch_normalization_80[0][0]']
#
#  activation_72 (Activation)     (None, 14, 14, 1024  0           ['add_23[0][0]']
#                                 )
#
#  conv2d_81 (Conv2D)             (None, 14, 14, 512)  524800      ['activation_72[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_81[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 14, 14, 512)  2359808     ['activation_73[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_82[0][0]']
#  ormalization)
#
#  activation_74 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_82[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_74[0][0]']
#                                 )
#
#  batch_normalization_83 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_83[0][0]']
#  ormalization)                  )
#
#  add_24 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_83[0][0]',
#                                 )                                 'activation_72[0][0]']
#
#  activation_75 (Activation)     (None, 14, 14, 1024  0           ['add_24[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 14, 14, 512)  524800      ['activation_75[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_84[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 14, 14, 512)  2359808     ['activation_76[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_85[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_77[0][0]']
#                                 )
#
#  batch_normalization_86 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_86[0][0]']
#  ormalization)                  )
#
#  add_25 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_86[0][0]',
#                                 )                                 'activation_75[0][0]']
#
#  activation_78 (Activation)     (None, 14, 14, 1024  0           ['add_25[0][0]']
#                                 )
#
#  conv2d_87 (Conv2D)             (None, 14, 14, 512)  524800      ['activation_78[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_87[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_87[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 14, 14, 512)  2359808     ['activation_79[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_88[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_80[0][0]']
#                                 )
#
#  batch_normalization_89 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_89[0][0]']
#  ormalization)                  )
#
#  add_26 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_89[0][0]',
#                                 )                                 'activation_78[0][0]']
#
#  activation_81 (Activation)     (None, 14, 14, 1024  0           ['add_26[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 14, 14, 512)  524800      ['activation_81[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_82 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_90[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 14, 14, 512)  2359808     ['activation_82[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_91[0][0]']
#  ormalization)
#
#  activation_83 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_91[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_83[0][0]']
#                                 )
#
#  batch_normalization_92 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_92[0][0]']
#  ormalization)                  )
#
#  add_27 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_92[0][0]',
#                                 )                                 'activation_81[0][0]']
#
#  activation_84 (Activation)     (None, 14, 14, 1024  0           ['add_27[0][0]']
#                                 )
#
#  conv2d_93 (Conv2D)             (None, 14, 14, 512)  524800      ['activation_84[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_93[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 14, 14, 512)  2359808     ['activation_85[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_86[0][0]']
#                                 )
#
#  batch_normalization_95 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_95[0][0]']
#  ormalization)                  )
#
#  add_28 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_95[0][0]',
#                                 )                                 'activation_84[0][0]']
#
#  activation_87 (Activation)     (None, 14, 14, 1024  0           ['add_28[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 14, 14, 1024  1049600     ['activation_87[0][0]']
#                                 )
#
#  batch_normalization_96 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_96[0][0]']
#  ormalization)                  )
#
#  activation_88 (Activation)     (None, 14, 14, 1024  0           ['batch_normalization_96[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 7, 7, 1024)   9438208     ['activation_88[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_97[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 7, 7, 2048)   2099200     ['activation_89[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 7, 7, 2048)   2099200     ['activation_87[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_98[0][0]']
#  ormalization)
#
#  batch_normalization_99 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_99[0][0]']
#  ormalization)
#
#  add_29 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_98[0][0]',
#                                                                   'batch_normalization_99[0][0]']
#
#  activation_90 (Activation)     (None, 7, 7, 2048)   0           ['add_29[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 7, 7, 1024)   2098176     ['activation_90[0][0]']
#
#  batch_normalization_100 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_100[0][0]']
#  Normalization)
#
#  activation_91 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_100[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 7, 7, 1024)   9438208     ['activation_91[0][0]']
#
#  batch_normalization_101 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_101[0][0]']
#  Normalization)
#
#  activation_92 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_101[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 7, 7, 2048)   2099200     ['activation_92[0][0]']
#
#  batch_normalization_102 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_102[0][0]']
#  Normalization)
#
#  add_30 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_102[0][0]',
#                                                                   'activation_90[0][0]']
#
#  activation_93 (Activation)     (None, 7, 7, 2048)   0           ['add_30[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 7, 7, 1024)   2098176     ['activation_93[0][0]']
#
#  batch_normalization_103 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_94 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_103[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 7, 7, 1024)   9438208     ['activation_94[0][0]']
#
#  batch_normalization_104 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_104[0][0]']
#  Normalization)
#
#  activation_95 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 7, 7, 2048)   2099200     ['activation_95[0][0]']
#
#  batch_normalization_105 (Batch  (None, 7, 7, 2048)  8192        ['conv2d_105[0][0]']
#  Normalization)
#
#  add_31 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_105[0][0]',
#                                                                   'activation_93[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['add_31[0][0]']
#  obalAveragePooling2D)
#
#  flatten_1 (Flatten)            (None, 2048)         0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_1 (Dense)                (None, 71)           145479      ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 67,082,055
# Trainable params: 67,013,831
# Non-trainable params: 68,224
# __________________________________________________________________________________________________

# %%
# Ajout de l'optimiseur, de la fonction coût et des métriques
model.compile(tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0.9), loss='categorical_crossentropy', metrics=['categorical_accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
def weight_class_i(nb_elts, nb_class, nb_img):
  return (nb_img/(nb_class*nb_elts))

# %%
# Détermination des poids à attribuer à chaque classe
import pathlib

nb_files = 0
class_weight = {}
for i in range(nb_classes):
  for path in pathlib.Path("abeilles-cap500/train/" + class_names[i]).iterdir():
    if path.is_file():
        nb_files += 1
  class_weight[i] = weight_class_i(nb_files, nb_classes, len(train_ds.file_paths))
  nb_files = 0
print(class_weight)
# Out:
# {0: 1.265654165959613, 1: 1.8758802816901408, 2: 2.414926339647078, 3: 0.5252464788732394, 4: 1.0452666246233622, 5: 2.918035993740219, 6: 1.029895056614195, 7: 1.2215034392400916, 8: 0.5252464788732394, 9: 2.7285531370038414, 10: 0.5252464788732394, 11: 0.6089814247805675, 12: 1.3822275759822091, 13: 1.235874067937034, 14: 2.334428794992175, 15: 3.622389509470617, 16: 0.5252464788732394, 17: 1.9820621844273185, 18: 1.8758802816901408, 19: 0.8471717401181281, 20: 0.6956907004943569, 21: 1.8269442743417024, 22: 1.842970101309612, 23: 2.0397921509640367, 24: 2.659475842396149, 25: 0.5602629107981221, 26: 0.5252464788732394, 27: 1.4006572769953052, 28: 1.654319618498392, 29: 1.207463169823539, 30: 0.7928248737709275, 31: 1.2733247972684592, 32: 0.5252464788732394, 33: 0.5252464788732394, 34: 0.7781429316640585, 35: 2.7285531370038414, 36: 0.5252464788732394, 37: 0.5252464788732394, 38: 2.8013145539906104, 39: 0.7295089984350548, 40: 0.5968709987195903, 41: 1.4489558037882466, 42: 0.9817691193892326, 43: 0.7050288307023348, 44: 1.7508215962441314, 45: 0.7476818204601273, 46: 0.5252464788732394, 47: 0.5951801460319993, 48: 1.6943434802362562, 49: 0.5252464788732394, 50: 2.8391701560715643, 51: 1.9275100142137227, 52: 1.8927801040477097, 53: 2.1885269953051645, 54: 1.355474784189005, 55: 2.1885269953051645, 56: 1.3731934088189266, 57: 1.0248711782892477, 58: 1.7957144576862887, 59: 1.2733247972684592, 60: 2.3606583320145593, 61: 2.593809772213528, 62: 1.2889484144128576, 63: 0.5252464788732394, 64: 2.2591246403150085, 65: 0.5252464788732394, 66: 1.5335663616736919, 67: 1.7508215962441314, 68: 0.7346104599625727, 69: 1.6286712523201223, 70: 0.5252464788732394}

# %%
# Les callbacks
model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    filepath='./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2',
    save_weights_only=True,
    monitor='val_categorical_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    monitor="val_categorical_accuracy",
    min_delta=0.01,
    patience=10,
    verbose=1,
    mode="auto")

reduce_lr_cb = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_categorical_accuracy', factor=0.1,
                              patience=5, min_lr=0.00001, verbose=1)

# %%
train_ds_aug = AbeillesSequence(x_train, y_train, batch_size=16, augmentations=AUGMENTATIONS_TRAIN)

# %%
import numpy as np
import tensorflow as tf
# Normalisation des données de validation
x_val = np.zeros((1832, IMG_SIZE, IMG_SIZE, 3))
y_val = np.zeros((1832, NB_CLASSES))

ind_data = 0
for bx, by in validation_ds.as_numpy_iterator():
  x_val[ind_data:ind_data+bx.shape[0]] = bx
  y_val[ind_data:ind_data+bx.shape[0]] = by
  ind_data += bx.shape[0]

x_val = color_preprocessing(x_val)

# %%
# Sans pondération des classes
history = model.fit(train_ds_aug, epochs=150, validation_data = (x_val, y_val), callbacks=[model_checkpoint_cb, early_stopping_cb, reduce_lr_cb])
# Avec pondération des classes
#model.fit(train_ds_aug, epochs=150, validation_data = (x_val, y_val), callbacks=[model_checkpoint_cb, early_stopping_cb, reduce_lr_cb], class_weight=class_weight)
# Out:
# Epoch 1/150
# 933/933 [==============================] - ETA: 0s - loss: 38.2502 - categorical_accuracy: 0.0461 - precision_1: 0.1111 - recall_1: 0.0013
# Epoch 1: val_categorical_accuracy improved from -inf to 0.06932, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 394s 399ms/step - loss: 38.2502 - categorical_accuracy: 0.0461 - precision_1: 0.1111 - recall_1: 0.0013 - val_loss: 37.9996 - val_categorical_accuracy: 0.0693 - val_precision_1: 0.1089 - val_recall_1: 0.0060 - lr: 0.0010
# Epoch 2/150
# 933/933 [==============================] - ETA: 0s - loss: 37.4635 - categorical_accuracy: 0.0659 - precision_1: 0.1609 - recall_1: 0.0025
# Epoch 2: val_categorical_accuracy improved from 0.06932 to 0.07424, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 376s 403ms/step - loss: 37.4635 - categorical_accuracy: 0.0659 - precision_1: 0.1609 - recall_1: 0.0025 - val_loss: 37.1615 - val_categorical_accuracy: 0.0742 - val_precision_1: 0.0435 - val_recall_1: 0.0016 - lr: 0.0010
# Epoch 3/150
# 933/933 [==============================] - ETA: 0s - loss: 36.7062 - categorical_accuracy: 0.0874 - precision_1: 0.2611 - recall_1: 0.0040
# Epoch 3: val_categorical_accuracy improved from 0.07424 to 0.11736, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 393ms/step - loss:
saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 393ms/step - loss: 27.5900 - categorical_accuracy: 0.4003 - precision_1: 0.7102 - recall_1: 0.2082 - val_loss: 27.7444 - val_categorical_accuracy: 0.4531 - val_precision_1: 0.6815 - val_recall_1: 0.3002 - lr: 0.0010
# Epoch 18/150
# 933/933 [==============================] - ETA: 0s - loss: 27.0640 - categorical_accuracy: 0.4201 - precision_1: 0.7072 - recall_1: 0.2283
# Epoch 18: val_categorical_accuracy improved from 0.45306 to 0.45579, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 393ms/step - loss: 27.0640 - categorical_accuracy: 0.4201 - precision_1: 0.7072 - recall_1: 0.2283 - val_loss: 27.0427 - val_categorical_accuracy: 0.4558 - val_precision_1: 0.6640 - val_recall_1: 0.3139 - lr: 0.0010
# Epoch 19/150
# 933/933 [==============================] - ETA: 0s - loss: 26.5519 - categorical_accuracy: 0.4325 - precision_1: 0.7096 - recall_1: 0.2461
# Epoch 19: val_categorical_accuracy did not improve from 0.45579
# 933/933 [==============================] - 364s 390ms/step - loss: 26.5519 - categorical_accuracy: 0.4325 - precision_1: 0.7096 - recall_1: 0.2461 - val_loss: 27.0127 - val_categorical_accuracy: 0.4514 - val_precision_1: 0.6473 - val_recall_1: 0.2975 - lr: 0.0010
# Epoch 20/150
# 933/933 [==============================] - ETA: 0s - loss: 26.0636 - categorical_accuracy: 0.4422 - precision_1: 0.7213 - recall_1: 0.2622
# Epoch 20: val_categorical_accuracy improved from 0.45579 to 0.46015, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 393ms/step - loss: 26.0636 - categorical_accuracy: 0.4422 - precision_1: 0.7213 - recall_1: 0.2622 - val_loss: 26.2470 - val_categorical_accuracy: 0.4602 - val_precision_1: 0.6694 - val_recall_1: 0.3128 - lr: 0.0010
# Epoch 21/150
# 933/933 [==============================] - ETA: 0s - loss: 25.5597 - categorical_accuracy: 0.4585 - precision_1: 0.7302 - recall_1: 0.2826
# Epoch 21: val_categorical_accuracy improved from 0.46015 to 0.47052, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 393ms/step - loss: 25.5597 - categorical_accuracy: 0.4585 - precision_1: 0.7302 - recall_1: 0.2826 - val_loss: 26.1222 - val_categorical_accuracy: 0.4705 - val_precision_1: 0.6700 - val_recall_1: 0.3335 - lr: 0.0010
# Epoch 22/150
# 933/933 [==============================] - ETA: 0s - loss: 25.0972 - categorical_accuracy: 0.4679 - precision_1: 0.7217 - recall_1: 0.2890
# Epoch 22: val_categorical_accuracy improved from 0.47052 to 0.50164, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 393ms/step - loss: 25.0972 - categorical_accuracy: 0.4679 - precision_1: 0.7217 - recall_1: 0.2890 - val_loss: 24.9645 - val_categorical_accuracy: 0.5016 - val_precision_1: 0.6888 - val_recall_1: 0.3734 - lr: 0.0010
# Epoch 23/150
# 933/933 [==============================] - ETA: 0s - loss: 24.6236 - categorical_accuracy: 0.4809 - precision_1: 0.7314 - recall_1: 0.3090
# Epoch 23: val_categorical_accuracy improved from 0.50164 to 0.51201, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 393ms/step - loss: 24.6236 - categorical_accuracy: 0.4809 - precision_1: 0.7314 - recall_1: 0.3090 - val_loss: 24.8029 - val_categorical_accuracy: 0.5120 - val_precision_1: 0.7153 - val_recall_1: 0.3881 - lr: 0.0010
# Epoch 24/150
# 933/933 [==============================] - ETA: 0s - loss: 24.1630 - categorical_accuracy: 0.4948 - precision_1: 0.7459 - recall_1: 0.3269
# Epoch 24: val_categorical_accuracy improved from 0.51201 to 0.51365, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 393ms/step - loss:
# Epoch 31/150
# 933/933 [==============================] - ETA: 0s - loss: 21.2184 - categorical_accuracy: 0.5633 - precision_1: 0.7758 - recall_1: 0.4243
# Epoch 31: val_categorical_accuracy did not improve from 0.55295
# 933/933 [==============================] - 365s 391ms/step - loss: 21.2184 - categorical_accuracy: 0.5633 - precision_1: 0.7758 - recall_1: 0.4243 - val_loss: 21.5996 - val_categorical_accuracy: 0.5453 - val_precision_1: 0.7288 - val_recall_1: 0.4460 - lr: 0.0010
# Epoch 32/150
# 933/933 [==============================] - ETA: 0s - loss: 20.8456 - categorical_accuracy: 0.5728 - precision_1: 0.7845 - recall_1: 0.4272
# Epoch 32: val_categorical_accuracy improved from 0.55295 to 0.56550, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 393ms/step - loss: 20.8456 - categorical_accuracy: 0.5728 - precision_1: 0.7845 - recall_1: 0.4272 - val_loss: 21.5999 - val_categorical_accuracy: 0.5655 - val_precision_1: 0.7161 - val_recall_1: 0.4820 - lr: 0.0010
# Epoch 33/150
# 933/933 [==============================] - ETA: 0s - loss: 20.4628 - categorical_accuracy: 0.5807 - precision_1: 0.7833 - recall_1: 0.4409
# Epoch 33: val_categorical_accuracy improved from 0.56550 to 0.56769, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 376s 403ms/step - loss: 20.4628 - categorical_accuracy: 0.5807 - precision_1: 0.7833 - recall_1: 0.4409 - val_loss: 20.7478 - val_categorical_accuracy: 0.5677 - val_precision_1: 0.7241 - val_recall_1: 0.4771 - lr: 0.0010
# Epoch 34/150
# 933/933 [==============================] - ETA: 0s - loss: 20.1098 - categorical_accuracy: 0.5850 - precision_1: 0.7854 - recall_1: 0.4486
# Epoch 34: val_categorical_accuracy improved from 0.56769 to 0.58570, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 394ms/step - loss: 20.1098 - categorical_accuracy: 0.5850 - precision_1: 0.7854 - recall_1: 0.4486 - val_loss: 20.7027 - val_categorical_accuracy: 0.5857 - val_precision_1: 0.7279 - val_recall_1: 0.4820 - lr: 0.0010
# Epoch 35/150
# 933/933 [==============================] - ETA: 0s - loss: 19.7448 - categorical_accuracy: 0.5918 - precision_1: 0.7858 - recall_1: 0.4598
# Epoch 35: val_categorical_accuracy improved from 0.58570 to 0.59334, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 368s 394ms/step - loss: 19.7448 - categorical_accuracy: 0.5918 - precision_1: 0.7858 - recall_1: 0.4598 - val_loss: 20.2226 - val_categorical_accuracy: 0.5933 - val_precision_1: 0.7415 - val_recall_1: 0.5011 - lr: 0.0010
# Epoch 36/150
# 933/933 [==============================] - ETA: 0s - loss: 19.3835 - categorical_accuracy: 0.6035 - precision_1: 0.7913 - recall_1: 0.4712
# Epoch 36: val_categorical_accuracy did not improve from 0.59334
# 933/933 [==============================] - 365s 391ms/step - loss: 19.3835 - categorical_accuracy: 0.6035 - precision_1: 0.7913 - recall_1: 0.4712 - val_loss: 19.7134 - val_categorical_accuracy: 0.5802 - val_precision_1: 0.7343 - val_recall_1: 0.4782 - lr: 0.0010
# Epoch 37/150
# 933/933 [==============================] - ETA: 0s - loss: 19.0283 - categorical_accuracy: 0.6138 - precision_1: 0.7983 - recall_1: 0.4838
# Epoch 37: val_categorical_accuracy did not improve from 0.59334
# 933/933 [==============================] - 364s 390ms/step - loss: 19.0283 - categorical_accuracy: 0.6138 - precision_1: 0.7983 - recall_1: 0.4838 - val_loss: 19.4623 - val_categorical_accuracy: 0.5830 - val_precision_1: 0.7159 - val_recall_1: 0.4951 - lr: 0.0010
# Epoch 38/150
# 933/933 [==============================] - ETA: 0s - loss: 18.6786 - categorical_accuracy: 0.6248 - precision_1: 0.8087 - recall_1: 0.4975
# Epoch 38: val_categorical_accuracy improved from 0.59334 to 0.60917, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 393ms/step - loss: 18.6786 - categorical_accuracy: 0.6248 - precision_1: 0.8087 - recall_1: 0.4975 - val_loss: 19.0301 - val_categorical_accuracy: 0.6092 - val_precision_1: 0.7447 - val_recall_1: 0.5207 - lr: 0.0010
# Epoch 39/150
# 933/933 [==============================] - ETA: 0s - loss: 18.3489 - categorical_accuracy: 0.6252 - precision_1: 0.8042 - recall_1: 0.5024
# Epoch 39: val_categorical_accuracy improved from 0.60917 to 0.61026, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 368s 394ms/step - loss: 18.3489 - categorical_accuracy: 0.6252 - precision_1: 0.8042 - recall_1: 0.5024 - val_loss: 18.6845 - val_categorical_accuracy: 0.6103 - val_precision_1: 0.7522 - val_recall_1: 0.5235 - lr: 0.0010
# Epoch 40/150
# 933/933 [==============================] - ETA: 0s - loss: 18.0294 - categorical_accuracy: 0.6310 - precision_1: 0.8007 - recall_1: 0.5086
# Epoch 40: val_categorical_accuracy did not improve from 0.61026
# 933/933 [==============================] - 374s 401ms/step - loss: 18.0294 - categorical_accuracy: 0.6310 - precision_1: 0.8007 - recall_1: 0.5086 - val_loss: 18.5544 - val_categorical_accuracy: 0.5922 - val_precision_1: 0.7463 - val_recall_1: 0.5169 - lr: 0.0010
# Epoch 41/150
# 933/933 [==============================] - ETA: 0s - loss: 17.6840 - categorical_accuracy: 0.6451 - precision_1: 0.8141 - recall_1: 0.5307
# Epoch 41: val_categorical_accuracy improved from 0.61026 to 0.62118, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 394ms/step - loss: 17.6840 - categorical_accuracy: 0.6451 - precision_1: 0.8141 - recall_1: 0.5307 - val_loss: 17.7803 - val_categorical_accuracy: 0.6212 - val_precision_1: 0.7452 - val_recall_1: 0.5459 - lr: 0.0010
# Epoch 42/150
# 933/933 [==============================] - ETA: 0s - loss: 17.3850 - categorical_accuracy: 0.6481 - precision_1: 0.8111 - recall_1: 0.5319
# Epoch 42: val_categorical_accuracy did not improve from 0.62118
# 933/933 [==============================] - 365s 391ms/step - loss: 17.3850 - categorical_accuracy: 0.6481 - precision_1: 0.8111 - recall_1: 0.5319 - val_loss: 18.2065 - val_categorical_accuracy: 0.5781 - val_precision_1: 0.7178 - val_recall_1: 0.4956 - lr: 0.0010
# Epoch 43/150
# 933/933 [==============================] - ETA: 0s - loss: 17.0740 - categorical_accuracy: 0.6539 - precision_1: 0.8178 - recall_1: 0.5383
# Epoch 43: val_categorical_accuracy did not improve from 0.62118
# 933/933 [==============================] - 365s 391ms/step - loss: 17.0740 - categorical_accuracy: 0.6539 - precision_1: 0.8178 - recall_1: 0.5383 - val_loss: 17.2514 - val_categorical_accuracy: 0.6190 - val_precision_1: 0.7641 - val_recall_1: 0.5464 - lr: 0.0010
# Epoch 44/150
# 933/933 [==============================] - ETA: 0s - loss: 16.7751 - categorical_accuracy: 0.6594 - precision_1: 0.8137 - recall_1: 0.5474
# Epoch 44: val_categorical_accuracy improved from 0.62118 to 0.62718, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 367s 394ms/step - loss: 16.7751 - categorical_accuracy: 0.6594 - precision_1: 0.8137 - recall_1: 0.5474 - val_loss: 16.8816 - val_categorical_accuracy: 0.6272 - val_precision_1: 0.7523 - val_recall_1: 0.5453 - lr: 0.0010
# Epoch 45/150
# 933/933 [==============================] - ETA: 0s - loss: 16.4820 - categorical_accuracy: 0.6668 - precision_1: 0.8186 - recall_1: 0.5552
# Epoch 45: val_categorical_accuracy improved from 0.62718 to 0.62937, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 377s 404ms/step - loss: 16.4820 - categorical_accuracy: 0.6668 - precision_1: 0.8186 - recall_1: 0.5552 - val_loss: 16.6305 - val_categorical_accuracy: 0.6294 - val_precision_1: 0.7613 - val_recall_1: 0.5606 - lr: 0.0010
# Epoch 46/150
# 933/933 [==============================] - ETA: 0s - loss: 16.1465 - categorical_accuracy: 0.6830 - precision_1: 0.8269 - recall_1: 0.5740
# Epoch 46: val_categorical_accuracy improved from 0.62937 to 0.64138, saving model to ./drive/MyDrive/Stage2A/cap500/WideResNet50-2/PoidsWR50-2/best_model_wideresnet50-2
# 933/933 [==============================] - 368s 394ms/step - loss: 16.1465 - categorical_accuracy: 0.6830 - precision_1: 0.8269 - recall_1: 0.5740 - val_loss: 16.2730 - val_categorical_accuracy: 0.6414 - val_precision_1: 0.7652 - val_recall_1: 0.5835 - lr: 0.0010
# Epoch 47/150
# 933/933 [==============================] - ETA: 0s - loss: 15.8830 - categorical_accuracy: 0.6818 - precision_1: 0.8257 - recall_1: 0.5767
# Epoch 47: val_categorical_accuracy did not improve from 0.64138
# 933/933 [==============================] - 365s 391ms/step - loss: 15.8830 - categorical_accuracy: 0.6818 - precision_1: 0.8257 - recall_1: 0.5767 - val_loss: 16.2834 - val_categorical_accuracy: 0.6135 - val_precision_1: 0.7398 - val_recall_1: 0.5448 - lr: 0.0010
# Epoch 48/150
# 933/933 [==============================] - ETA: 0s - loss: 15.6256 - categorical_accuracy: 0.6811 - precision_1: 0.8252 - recall_1: 0.5793
# Epoch 48: val_categorical_accuracy did not improve from 0.64138
# 933/933 [==============================] - 365s 391ms/step - loss: 15.6256 - categorical_accuracy: 0.6811 - precision_1: 0.8252 - recall_1: 0.5793 - val_loss: 15.8048 - val_categorical_accuracy: 0.6348 - val_precision_1: 0.7580 - val_recall_1: 0.5660 - lr: 0.0010

# %%
import matplotlib.pyplot as plt
def plot_training_analysis(history, metric='loss'):    

  loss = history.history[metric]
  val_loss = history.history['val_' + metric]

  epochs = range(len(loss))

  plt.plot(epochs, loss, 'b', linestyle="--",label='Training ' + metric)
  plt.plot(epochs, val_loss, 'g', label='Validation ' + metric)
  plt.title('Training and validation ' + metric)
  plt.legend()

  plt.show()

# %%
plot_training_analysis(history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ecf040265733> in <module>()
# ----> 1 plot_training_analysis(history)
#
# NameError: name 'history' is not defined
